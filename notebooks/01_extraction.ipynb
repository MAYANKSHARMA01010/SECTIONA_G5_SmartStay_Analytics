# %%
import pandas as pd
import numpy as np

# %%
file_path = "../data/raw/airbnb_listing.csv"

df = pd.read_csv(file_path)
df.head()
# Out:
#   host_response_rate  host_total_listings_count  review_scores_accuracy  \
# 0                NaN                        NaN                    3.44
# 1                NaN                        NaN                    4.88
# 2                NaN                        NaN                    4.61
# 3                NaN                        NaN                     NaN
# 4                NaN                        NaN                    4.83
#
#   host_acceptance_rate  availability_90 neighbourhood_cleansed  \
# 0                  NaN             46.0             THIRD WARD
# 1                  NaN             26.0             SIXTH WARD
# 2                  NaN             35.0            SECOND WARD
# 3                  NaN             71.0        THIRTEENTH WARD
# 4                  NaN             73.0             SIXTH WARD
#
#    availability_60  bedrooms  review_scores_cleanliness host_response_time  \
# 0             16.0       2.0                       3.56                NaN
# 1              0.0       1.0                       4.87                NaN
# 2             31.0       0.0                       4.45                NaN
# 3             45.0       3.0                        NaN                NaN
# 4             43.0       1.0                       4.71                NaN
#
#    ...  host_since number_of_reviews  review_scores_location  price  \
# 0  ...         NaN               9.0                    3.22    NaN
# 1  ...         NaN             317.0                    4.82    NaN
# 2  ...         NaN             389.0                    4.76    NaN
# 3  ...         NaN               0.0                     NaN    NaN
# 4  ...         NaN             332.0                    4.80    NaN
#
#   review_scores_communication  number_of_reviews_ltm  review_scores_value  \
# 0                        4.56                    0.0                 3.67
# 1                        4.81                   10.0                 4.78
# 2                        4.86                   20.0                 4.63
# 3                         NaN                    0.0                  NaN
# 4                        4.70                    1.0                 4.72
#
#    availability_30  beds availability_365
# 0              0.0   2.0            321.0
# 1              0.0   1.0            301.0
# 2             18.0   2.0             35.0
# 3             20.0   3.0            324.0
# 4             13.0   1.0            348.0
#
# [5 rows x 38 columns]

# %%
df.shape
# Out:
# (42904, 38)

# %%
df.columns.tolist()
# Out:
# ['host_response_rate',
#  'host_total_listings_count',
#  'review_scores_accuracy',
#  'host_acceptance_rate',
#  'availability_90',
#  'neighbourhood_cleansed',
#  'availability_60',
#  'bedrooms',
#  'review_scores_cleanliness',
#  'host_response_time',
#  'reviews_per_month',
#  'amenities',
#  'host_listings_count',
#  'longitude',
#  'room_type',
#  'bathrooms',
#  'review_scores_rating',
#  'estimated_occupancy_l365d',
#  'estimated_revenue_l365d',
#  'property_type',
#  'number_of_reviews_ly',
#  'review_scores_checkin',
#  'accommodates',
#  'latitude',
#  'maximum_nights',
#  'instant_bookable',
#  'host_is_superhost',
#  'minimum_nights',
#  'host_since',
#  'number_of_reviews',
#  'review_scores_location',
#  'price',
#  'review_scores_communication',
#  'number_of_reviews_ltm',
#  'review_scores_value',
#  'availability_30',
#  'beds',
#  'availability_365']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 42904 entries, 0 to 42903
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   host_response_rate           32295 non-null  str
#  1   host_total_listings_count    42424 non-null  float64
#  2   review_scores_accuracy       35784 non-null  float64
#  3   host_acceptance_rate         35340 non-null  str
#  4   availability_90              42902 non-null  float64
#  5   neighbourhood_cleansed       42902 non-null  str
#  6   availability_60              42902 non-null  float64
#  7   bedrooms                     41363 non-null  float64
#  8   review_scores_cleanliness    35781 non-null  float64
#  9   host_response_time           32294 non-null  str
#  10  reviews_per_month            35783 non-null  float64
#  11  amenities                    42902 non-null  str
#  12  host_listings_count          42876 non-null  float64
#  13  longitude                    42902 non-null  float64
#  14  room_type                    42902 non-null  str
#  15  bathrooms                    33090 non-null  float64
#  16  review_scores_rating         35783 non-null  float64
#  17  estimated_occupancy_l365d    42902 non-null  float64
#  18  estimated_revenue_l365d      32585 non-null  float64
#  19  property_type                42902 non-null  str
#  20  number_of_reviews_ly         42902 non-null  float64
#  21  review_scores_checkin        35780 non-null  float64
#  22  accommodates                 42902 non-null  float64
#  23  latitude                     42902 non-null  float64
#  24  maximum_nights               42902 non-null  float64
#  25  instant_bookable             42449 non-null  str
#  26  host_is_superhost            41329 non-null  str
#  27  minimum_nights               42902 non-null  float64
#  28  host_since                   42424 non-null  str
#  29  number_of_reviews            42902 non-null  float64
#  30  review_scores_location       35779 non-null  float64
#  31  price                        32585 non-null  str
#  32  review_scores_communication  35782 non-null  float64
#  33  number_of_reviews_ltm        42902 non-null  float64
#  34  review_scores_value          35778 non-null  float64
#  35  availability_30              42902 non-null  float64
#  36  beds                         32976 non-null  float64
#  37  availability_365             42901 non-null  float64
# dtypes: float64(27), str(11)
# memory usage: 12.4 MB

# %%
df.describe()
# Out:
#        host_total_listings_count  review_scores_accuracy  availability_90  \
# count               42424.000000            3.578400e+04     42902.000000
# mean                   34.425726            7.977322e+01        45.216237
# std                   164.376987            1.418223e+04        34.015698
# min                     0.000000            1.000000e+00         0.000000
# 25%                     1.000000            4.750000e+00         1.000000
# 50%                     4.000000            4.900000e+00        54.000000
# 75%                    16.000000            5.000000e+00        76.000000
# max                  8774.000000            2.682808e+06        90.000000
#
#        availability_60      bedrooms  review_scores_cleanliness  \
# count     42902.000000  41363.000000               35781.000000
# mean         27.189875      1.506298                   4.756458
# std          22.122010      1.274222                   0.377259
# min           0.000000      0.000000                   0.000000
# 25%           0.000000      1.000000                   4.680000
# 50%          28.000000      1.000000                   4.870000
# 75%          48.000000      2.000000                   5.000000
# max          60.000000     50.000000                   5.000000
#
#        reviews_per_month  host_listings_count     longitude     bathrooms  \
# count       35783.000000         42876.000000  42902.000000  33090.000000
# mean            1.357060            23.472805     29.631573      1.300620
# std             1.940987            87.187957     49.407679      0.761264
# min             0.010000             0.000000    -82.669890      0.000000
# 25%             0.240000             1.000000      4.884932      1.000000
# 50%             0.660000             3.000000     23.725932      1.000000
# 75%             1.850000            13.000000    100.467605      1.500000
# max            99.420000          1649.000000    100.923710     22.000000
#
#        ...  maximum_nights  minimum_nights  number_of_reviews  \
# count  ...    42902.000000    42902.000000       42902.000000
# mean   ...      461.470491        7.751527          52.862827
# std    ...      806.064095       33.318036         109.404180
# min    ...        1.000000        1.000000           0.000000
# 25%    ...       50.000000        1.000000           2.000000
# 50%    ...      365.000000        2.000000          13.000000
# 75%    ...     1125.000000        3.000000          53.000000
# max    ...   100000.000000     1115.000000        5097.000000
#
#        review_scores_location  review_scores_communication  \
# count            35779.000000                 35782.000000
# mean                 4.726750                     4.857957
# std                  0.375201                     0.322518
# min                  0.000000                     0.000000
# 25%                  4.640000                     4.850000
# 50%                  4.830000                     4.960000
# 75%                  4.970000                     5.000000
# max                  5.000000                     5.000000
#
#        number_of_reviews_ltm  review_scores_value  availability_30  \
# count           42902.000000         35778.000000     42902.000000
# mean               10.251410             4.691585        11.109249
# std                21.362045             0.384735        10.771320
# min                 0.000000             0.000000         0.000000
# 25%                 0.000000             4.600000         0.000000
# 50%                 2.000000             4.780000         8.000000
# 75%                11.000000             4.910000        21.000000
# max              1304.000000             5.000000        30.000000
#
#                beds  availability_365
# count  32976.000000      42901.000000
# mean       2.038483        195.300179
# std        1.789059        139.875129
# min        0.000000          0.000000
# 25%        1.000000         39.000000
# 50%        2.000000        234.000000
# 75%        2.000000        334.000000
# max       50.000000        365.000000
#
# [8 rows x 27 columns]

# %%
# count missing values in each column

df.isnull().sum().sort_values(ascending=False)
# Out:
# host_response_time             10610
# host_response_rate             10609
# estimated_revenue_l365d        10319
# price                          10319
# beds                            9928
# bathrooms                       9814
# host_acceptance_rate            7564
# review_scores_value             7126
# review_scores_location          7125
# review_scores_checkin           7124
# review_scores_cleanliness       7123
# review_scores_communication     7122
# review_scores_rating            7121
# reviews_per_month               7121
# review_scores_accuracy          7120
# host_is_superhost               1575
# bedrooms                        1541
# host_since                       480
# host_total_listings_count        480
# instant_bookable                 455
# host_listings_count               28
# availability_365                   3
# accommodates                       2
# latitude                           2
# maximum_nights                     2
# number_of_reviews_ly               2
# estimated_occupancy_l365d          2
# minimum_nights                     2
# room_type                          2
# number_of_reviews                  2
# longitude                          2
# amenities                          2
# availability_60                    2
# number_of_reviews_ltm              2
# neighbourhood_cleansed             2
# availability_30                    2
# availability_90                    2
# property_type                      2
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(52)

# %% [markdown]
# ## Column Categorization
#
# ### 1. Target Variables (KPIs)
# - estimated_revenue_l365d
# - estimated_occupancy_l365d
#
# ### 2. Key Features for Analysis
# - room_type
# - price
# - accommodates
# - bedrooms, bathrooms, beds
# - amenities
# - neighbourhood_cleansed
# - host_is_superhost
#
# ### 3. Columns with High Missing Values
# - host_neighbourhood
# - neighborhood_overview
# - host_about
# - license
#
# ### 4. Columns to Drop (Completely Missing)
# - neighbourhood_group_cleansed
# - calendar_updated
#
# ### 5. Columns Requiring Type Conversion
# - price (object → float)
# - host_response_rate (% → float)
# - host_acceptance_rate (% → float)
# - date columns → datetime

# %% [markdown]
# ## Conclusion
#
# - Dataset contains 42,903 listings with 79 features
# - No duplicate rows found
# - Several columns have missing values, including some completely empty columns
# - Key variables for business problem identified
# - Data type inconsistencies observed in price and percentage fields
